# %%
# aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.43-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Using cached lxml-5.3.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from yfinance) (4.3.2)
# Requirement already satisfied: pytz>=2022.5 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.4-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.17.6-cp311-cp311-macosx_11_0_arm64.whl
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.9 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anna/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Downloading yfinance-0.2.43-py2.py3-none-any.whl (84 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached frozendict-2.4.4-py311-none-any.whl (16 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached lxml-5.3.0-cp311-cp311-macosx_10_9_universal2.whl (8.1 MB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, peewee, multitasking, soupsieve, lxml, html5lib, frozendict, beautifulsoup4, yfinance
# Successfully installed beautifulsoup4-4.12.3 frozendict-2.4.4 html5lib-1.1 lxml-5.3.0 multitasking-0.0.11 peewee-3.17.6 soupsieve-2.6 webencodings-0.5.1 yfinance-0.2.43

# %%
import requests
import os
import yfinance as yf

# Your API key
API_KEY = 'aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY'

# List of all Australian Stock Markets
symbols = ['CBA', 'BHP', 'RIO', 'CSL', 'NAB', 'WBC', 'ANZ', 'WES', 'MQG', 'GMG', 'FMG', 'WDS', 'RMD', 'TLS', 'WOW', 'TCL', 'ALL', 'WTC', 'QBE', 'REA', 'STO', 'COL', 'JHX', 'AMC', 'SUN', 'COH', 'BXB', 'XRO', 'ORG', 'SCG', 'REH', 'IAG', 'FPH', 'CPU', 'NST', 'SVW', 'PME', 'S32', 'SHL', 'CAR', 'SOL', 'ASX', 'TLC', 'SGP', 'MPL', 'RHC', 'MIN', 'QAN', 'APA', 'NXT', 'TWE', 'EDV', 'BSL', 'VCX', 'YAL', 'AFI', 'GPT', 'PLS', 'TPG', 'GQG', 'ORI', 'MGR', 'WOR', 'ALD', 'SEK', 'EVN', 'JBH', 'ALX', 'DXS', 'SDF', 'BEN', 'AGL', 'AZJ', 'TNE', 'WHC', 'TLX', 'CHC', 'HVN', 'LYC', 'IPL', 'FLT', 'LLC', 'AWC', 'IGO', 'IEL', 'BOQ', 'NHC', 'HUB', 'SFR', 'VNT', 'SUL', 'PDN', 'AMP', 'BFL', 'ILU', 'NEU', 'DRR', 'SGM', 'CTD', 'IFL', 'MFG', 'KAR', 'DYL', 'CCP', 'TPW', 'OML', 'QRI', 'ADH', 'EML', 'GNG', 'DUG', 'WC8', 'KSL', 'TPC', 'PPE', 'AXI']

# Function to get full quote for a stock from FMP
def get_full_quote_fmp(symbol):
    symbol_with_suffix = f'{symbol}.AX'
    url = f'https://financialmodelingprep.com/api/v3/quote/{symbol_with_suffix}?apikey={API_KEY}'
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        data = response.json()
        if data and isinstance(data, list) and len(data) > 0:
            return data
        else:
            print(f'No data returned from FMP for symbol {symbol_with_suffix}')
            return None
    except requests.RequestException as e:
        print(f'Error fetching data from FMP for symbol {symbol_with_suffix}: {e}')
        return None

# Function to get full quote for a stock from Yahoo Finance
def get_full_quote_yf(symbol):
    symbol_with_suffix = f'{symbol}.AX'
    ticker = yf.Ticker(symbol_with_suffix)
    data = ticker.info
    if data:
        return [data]
    else:
        print(f'No data returned from Yahoo Finance for symbol {symbol_with_suffix}')
        return None

# Function to save data to a .txt file
def save_to_txt(data, directory, filename):
    if not os.path.exists(directory):
        os.makedirs(directory)

    file_path = os.path.join(directory, filename)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(str(data))  # Convert data to a string representation for saving

# Directory to save the quotes
directory = 'full_quote'

# Fetch and save quotes for each symbol
for symbol in symbols:
    full_quote = get_full_quote_fmp(symbol)

    # If FMP data is empty, fallback to Yahoo Finance
    if not full_quote:
        print(f'Fallback to Yahoo Finance for symbol {symbol}')
        full_quote = get_full_quote_yf(symbol)

    # Only save if data is returned
    if full_quote:
        filename = f'{symbol}_full_quote.txt'
        save_to_txt(full_quote, directory, filename)
        print(f'Saved data for {symbol} to {filename}')
    else:
        print(f'No data to save for {symbol}')
# Out:
# Error fetching data from FMP for symbol CBA.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/CBA.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol CBA
# Saved data for CBA to CBA_full_quote.txt
# Error fetching data from FMP for symbol BHP.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/BHP.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol BHP
# Saved data for BHP to BHP_full_quote.txt
# Error fetching data from FMP for symbol RIO.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/RIO.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol RIO
# Saved data for RIO to RIO_full_quote.txt
# Error fetching data from FMP for symbol CSL.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/CSL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol CSL
# Saved data for CSL to CSL_full_quote.txt
# Error fetching data from FMP for symbol NAB.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/NAB.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol NAB
# Saved data for NAB to NAB_full_quote.txt
# Error fetching data from FMP for symbol WBC.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/WBC.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol WBC
# Saved data for WBC to WBC_full_quote.txt
# Error fetching data from FMP for symbol ANZ.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/ANZ.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol ANZ
# Saved data for ANZ to ANZ_full_quote.txt
# Error fetching data from FMP for symbol WES.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/WES.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol WES
# Saved data for WES to WES_full_quote.txt
# Error fetching data from FMP for symbol MQG.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/MQG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol MQG
# Saved data for MQG to MQG_full_quote.txt
# Error fetching data from FMP for symbol GMG.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/GMG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol GMG
# Saved data for GMG to GMG_full_quote.txt
# Error fetching data from FMP for symbol FMG.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/FMG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol FMG
# Saved data for FMG to FMG_full_quote.txt
# Error fetching data from FMP for symbol WDS.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/WDS.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol WDS
# Saved data for WDS to WDS_full_quote.txt
# Error fetching data from FMP for symbol RMD.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/RMD.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol RMD
# Saved data for RMD to RMD_full_quote.txt
# Error fetching data from FMP for symbol TLS.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/TLS.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol TLS
# Saved data for TLS to TLS_full_quote.txt
# Error fetching data from FMP for symbol WOW.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/WOW.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol WOW
# Saved data for WOW to WOW_full_quote.txt
# Error fetching data from FMP for symbol TCL.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/TCL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol TCL
# Saved data for TCL to TCL_full_quote.txt
# Error fetching data from FMP for symbol ALL.AX: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/quote/ALL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol ALL
# Saved data for ALL to ALL_full_quote.txt
# Error fetching data from FMP for symbol WTC.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/WTC.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol WTC
# Saved data for WTC to WTC_full_quote.txt
# Error fetching data from FMP for symbol QBE.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/QBE.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol QBE
# Saved data for QBE to QBE_full_quote.txt
# Error fetching data from FMP for symbol REA.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/REA.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol REA
# Saved data for REA to REA_full_quote.txt
# Error fetching data from FMP for symbol STO.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/STO.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol STO
# Saved data for STO to STO_full_quote.txt
# Error fetching data from FMP for symbol COL.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/COL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol COL
# Saved data for COL to COL_full_quote.txt
# Error fetching data from FMP for symbol JHX.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/JHX.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol JHX
# Saved data for JHX to JHX_full_quote.txt
# Error fetching data from FMP for symbol AMC.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/AMC.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol AMC
# Saved data for AMC to AMC_full_quote.txt
# Error fetching data from FMP for symbol SUN.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SUN.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SUN
# Saved data for SUN to SUN_full_quote.txt
# Error fetching data from FMP for symbol COH.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/COH.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol COH
# Saved data for COH to COH_full_quote.txt
# Error fetching data from FMP for symbol BXB.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/BXB.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol BXB
# Saved data for BXB to BXB_full_quote.txt
# Error fetching data from FMP for symbol XRO.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/XRO.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol XRO
# Saved data for XRO to XRO_full_quote.txt
# Error fetching data from FMP for symbol ORG.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/ORG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol ORG
# Saved data for ORG to ORG_full_quote.txt
# Error fetching data from FMP for symbol SCG.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SCG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SCG
# Saved data for SCG to SCG_full_quote.txt
# Error fetching data from FMP for symbol REH.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/REH.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol REH
# Saved data for REH to REH_full_quote.txt
# Error fetching data from FMP for symbol IAG.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/IAG.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol IAG
# Saved data for IAG to IAG_full_quote.txt
# Error fetching data from FMP for symbol FPH.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/FPH.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol FPH
# Saved data for FPH to FPH_full_quote.txt
# Error fetching data from FMP for symbol CPU.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/CPU.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol CPU
# Saved data for CPU to CPU_full_quote.txt
# Error fetching data from FMP for symbol NST.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/NST.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol NST
# Saved data for NST to NST_full_quote.txt
# Error fetching data from FMP for symbol SVW.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SVW.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SVW
# Saved data for SVW to SVW_full_quote.txt
# Error fetching data from FMP for symbol PME.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/PME.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol PME
# Saved data for PME to PME_full_quote.txt
# Error fetching data from FMP for symbol S32.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/S32.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol S32
# Saved data for S32 to S32_full_quote.txt
# Error fetching data from FMP for symbol SHL.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SHL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SHL
# Saved data for SHL to SHL_full_quote.txt
# Error fetching data from FMP for symbol CAR.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/CAR.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol CAR
# Saved data for CAR to CAR_full_quote.txt
# Error fetching data from FMP for symbol SOL.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SOL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SOL
# Saved data for SOL to SOL_full_quote.txt
# Error fetching data from FMP for symbol ASX.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/ASX.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol ASX
# Saved data for ASX to ASX_full_quote.txt
# Error fetching data from FMP for symbol TLC.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/TLC.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol TLC
# Saved data for TLC to TLC_full_quote.txt
# Error fetching data from FMP for symbol SGP.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/SGP.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol SGP
# Saved data for SGP to SGP_full_quote.txt
# Error fetching data from FMP for symbol MPL.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/MPL.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol MPL
# Saved data for MPL to MPL_full_quote.txt
# Error fetching data from FMP for symbol RHC.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/RHC.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol RHC
# Saved data for RHC to RHC_full_quote.txt
# Error fetching data from FMP for symbol MIN.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/MIN.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol MIN
# Saved data for MIN to MIN_full_quote.txt
# Error fetching data from FMP for symbol QAN.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/QAN.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol QAN
# Saved data for QAN to QAN_full_quote.txt
# Error fetching data from FMP for symbol APA.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/APA.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol APA
# Saved data for APA to APA_full_quote.txt
# Error fetching data from FMP for symbol NXT.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/NXT.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol NXT
# Saved data for NXT to NXT_full_quote.txt
# Error fetching data from FMP for symbol TWE.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/TWE.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol TWE
# Saved data for TWE to TWE_full_quote.txt
# Error fetching data from FMP for symbol EDV.AX: 429 Client Error: Too Many Requests for url: https://financialmodelingprep.com/api/v3/quote/EDV.AX?apikey=aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY
# Fallback to Yahoo Finance for symbol EDV
# Saved data for EDV to EDV_full_quote.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 53
#      51 # Fetch and save quotes for each symbol
#      52 for symbol in symbols:
# ---> 53     full_quote = get_full_quote_fmp(symbol)
#      55     # If FMP data is empty, fallback to Yahoo Finance
#      56     if not full_quote:
#
# Cell In[3], line 16, in get_full_quote_fmp(symbol)
#      14 url = f'https://financialmodelingprep.com/api/v3/quote/{symbol_with_suffix}?apikey={API_KEY}'
#      15 try:
# ---> 16     response = requests.get(url)
#      17     response.raise_for_status()  # Check for HTTP errors
#      18     data = response.json()
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/MakeCents/E2_GenAI-6/.venv/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1315, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311     if flags != 0:
#    1312         raise ValueError(
#    1313           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1314           self.__class__)
# -> 1315     return self.read(nbytes, buffer)
#    1316 else:
#    1317     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
