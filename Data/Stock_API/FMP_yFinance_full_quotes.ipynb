# %%
# aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.41-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.4-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.6.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.5 MB/s eta 0:00:00a 0:00:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/anna/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/anna/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/anna/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/anna/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anna/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anna/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anna/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Downloading yfinance-0.2.41-py2.py3-none-any.whl (73 kB)
# Downloading frozendict-2.4.4-py311-none-any.whl (16 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.6-cp311-cp311-macosx_11_0_arm64.whl size=248939 sha256=b311dc33183c7e984ccecb7e39f38b5779940ce6261020c64953e297a0db406d
#   Stored in directory: /Users/anna/Library/Caches/pip/wheels/1c/09/7e/9f659fde248ecdc1722a142c1d744271aad3914a0afc191058
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.4.4 html5lib-1.1 multitasking-0.0.11 peewee-3.17.6 yfinance-0.2.41

# %%
import requests
import os
import yfinance as yf

# Your API key
API_KEY = 'aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY'

# List of all Australian Stock Markets
symbols = ['CBA', 'BHP', 'RIO', 'CSL', 'NAB', 'WBC', 'ANZ', 'WES', 'MQG', 'GMG', 'FMG', 'WDS', 'RMD', 'TLS', 'WOW', 'TCL', 'ALL', 'WTC', 'QBE', 'REA', 'STO', 'COL', 'JHX', 'AMC', 'SUN', 'COH', 'BXB', 'XRO', 'ORG', 'SCG', 'REH', 'IAG', 'FPH', 'CPU', 'NST', 'SVW', 'PME', 'S32', 'SHL', 'CAR', 'SOL', 'ASX', 'TLC', 'SGP', 'MPL', 'RHC', 'MIN', 'QAN', 'APA', 'NXT', 'TWE', 'EDV', 'BSL', 'VCX', 'YAL', 'AFI', 'GPT', 'PLS', 'TPG', 'GQG', 'ORI', 'MGR', 'WOR', 'ALD', 'SEK', 'EVN', 'JBH', 'ALX', 'DXS', 'SDF', 'BEN', 'AGL', 'AZJ', 'TNE', 'WHC', 'TLX', 'CHC', 'HVN', 'LYC', 'IPL', 'FLT', 'LLC', 'AWC', 'IGO', 'IEL', 'BOQ', 'NHC', 'HUB', 'SFR', 'VNT', 'SUL', 'PDN', 'AMP', 'BFL', 'ILU', 'NEU', 'DRR', 'SGM', 'CTD', 'IFL', 'MFG', 'KAR', 'DYL', 'CCP', 'TPW', 'OML', 'QRI', 'ADH', 'EML', 'GNG', 'DUG', 'WC8', 'KSL', 'TPC', 'PPE', 'AXI']

# Function to get full quote for a stock from FMP
def get_full_quote_fmp(symbol):
    url = f'https://financialmodelingprep.com/api/v3/quote/{symbol}?apikey={API_KEY}'
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        data = response.json()
        if data and isinstance(data, list) and len(data) > 0:
            return data
        else:
            print(f'No data returned from FMP for symbol {symbol}')
            return None
    except requests.RequestException as e:
        print(f'Error fetching data from FMP for symbol {symbol}: {e}')
        return None

# Function to get full quote for a stock from Yahoo Finance
def get_full_quote_yf(symbol):
    ticker = yf.Ticker(symbol)
    data = ticker.info
    if data:
        return [data]
    else:
        print(f'No data returned from Yahoo Finance for symbol {symbol}')
        return None

# Function to save data to a .txt file
def save_to_txt(data, directory, filename):
    if not os.path.exists(directory):
        os.makedirs(directory)

    file_path = os.path.join(directory, filename)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(str(data))  # Convert data to a string representation for saving

# Directory to save the quotes
directory = 'full_quote'

# Fetch and save quotes for each symbol
for symbol in symbols:
    full_quote = get_full_quote_fmp(symbol)

    # If FMP data is empty, fallback to Yahoo Finance
    if not full_quote:
        print(f'Fallback to Yahoo Finance for symbol {symbol}')
        full_quote = get_full_quote_yf(symbol)

    # Only save if data is returned
    if full_quote:
        filename = f'{symbol}_full_quote.txt'
        save_to_txt(full_quote, directory, filename)
        print(f'Saved data for {symbol} to {filename}')
    else:
        print(f'No data to save for {symbol}')
# Out:
# No data returned from FMP for symbol CBA
# Fallback to Yahoo Finance for symbol CBA
# Saved data for CBA to CBA_full_quote.txt
# Saved data for BHP to BHP_full_quote.txt
# Saved data for RIO to RIO_full_quote.txt
# Saved data for CSL to CSL_full_quote.txt
# No data returned from FMP for symbol NAB
# Fallback to Yahoo Finance for symbol NAB
# Saved data for NAB to NAB_full_quote.txt
# No data returned from FMP for symbol WBC
# Fallback to Yahoo Finance for symbol WBC
# Saved data for WBC to WBC_full_quote.txt
# No data returned from FMP for symbol ANZ
# Fallback to Yahoo Finance for symbol ANZ
# Saved data for ANZ to ANZ_full_quote.txt
# Saved data for WES to WES_full_quote.txt
# No data returned from FMP for symbol MQG
# Fallback to Yahoo Finance for symbol MQG
# Saved data for MQG to MQG_full_quote.txt
# No data returned from FMP for symbol GMG
# Fallback to Yahoo Finance for symbol GMG
# Saved data for GMG to GMG_full_quote.txt
# No data returned from FMP for symbol FMG
# Fallback to Yahoo Finance for symbol FMG
# Saved data for FMG to FMG_full_quote.txt
# Saved data for WDS to WDS_full_quote.txt
# Saved data for RMD to RMD_full_quote.txt
# Saved data for TLS to TLS_full_quote.txt
# Saved data for WOW to WOW_full_quote.txt
# No data returned from FMP for symbol TCL
# Fallback to Yahoo Finance for symbol TCL
# Saved data for TCL to TCL_full_quote.txt
# Saved data for ALL to ALL_full_quote.txt
# No data returned from FMP for symbol WTC
# Fallback to Yahoo Finance for symbol WTC
# Saved data for WTC to WTC_full_quote.txt
# No data returned from FMP for symbol QBE
# Fallback to Yahoo Finance for symbol QBE
# Saved data for QBE to QBE_full_quote.txt
# No data returned from FMP for symbol REA
# Fallback to Yahoo Finance for symbol REA
# Saved data for REA to REA_full_quote.txt
# No data returned from FMP for symbol STO
# Fallback to Yahoo Finance for symbol STO
# Saved data for STO to STO_full_quote.txt
# Saved data for COL to COL_full_quote.txt
# Saved data for JHX to JHX_full_quote.txt
# Saved data for AMC to AMC_full_quote.txt
# Saved data for SUN to SUN_full_quote.txt
# No data returned from FMP for symbol COH
# Fallback to Yahoo Finance for symbol COH
# Saved data for COH to COH_full_quote.txt
# No data returned from FMP for symbol BXB
# Fallback to Yahoo Finance for symbol BXB
# Saved data for BXB to BXB_full_quote.txt
# No data returned from FMP for symbol XRO
# Fallback to Yahoo Finance for symbol XRO
# Saved data for XRO to XRO_full_quote.txt
# Saved data for ORG to ORG_full_quote.txt
# No data returned from FMP for symbol SCG
# Fallback to Yahoo Finance for symbol SCG
# Saved data for SCG to SCG_full_quote.txt
# No data returned from FMP for symbol REH
# Fallback to Yahoo Finance for symbol REH
# Saved data for REH to REH_full_quote.txt
# Saved data for IAG to IAG_full_quote.txt
# Saved data for FPH to FPH_full_quote.txt
# No data returned from FMP for symbol CPU
# Fallback to Yahoo Finance for symbol CPU
# Saved data for CPU to CPU_full_quote.txt
# No data returned from FMP for symbol NST
# Fallback to Yahoo Finance for symbol NST
# Saved data for NST to NST_full_quote.txt
# No data returned from FMP for symbol SVW
# Fallback to Yahoo Finance for symbol SVW
# Saved data for SVW to SVW_full_quote.txt
# Saved data for PME to PME_full_quote.txt
# No data returned from FMP for symbol S32
# Fallback to Yahoo Finance for symbol S32
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/S32?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=S32&crumb=v44MHz9nj3f
# Saved data for S32 to S32_full_quote.txt
# No data returned from FMP for symbol SHL
# Fallback to Yahoo Finance for symbol SHL
# Saved data for SHL to SHL_full_quote.txt
# Saved data for CAR to CAR_full_quote.txt
# Saved data for SOL to SOL_full_quote.txt
# Saved data for ASX to ASX_full_quote.txt
# Saved data for TLC to TLC_full_quote.txt
# No data returned from FMP for symbol SGP
# Fallback to Yahoo Finance for symbol SGP
# Saved data for SGP to SGP_full_quote.txt
# No data returned from FMP for symbol MPL
# Fallback to Yahoo Finance for symbol MPL
# Saved data for MPL to MPL_full_quote.txt
# No data returned from FMP for symbol RHC
# Fallback to Yahoo Finance for symbol RHC
# Saved data for RHC to RHC_full_quote.txt
# Saved data for MIN to MIN_full_quote.txt
# No data returned from FMP for symbol QAN
# Fallback to Yahoo Finance for symbol QAN
# Saved data for QAN to QAN_full_quote.txt
# Saved data for APA to APA_full_quote.txt
# Saved data for NXT to NXT_full_quote.txt
# No data returned from FMP for symbol TWE
# Fallback to Yahoo Finance for symbol TWE
# Saved data for TWE to TWE_full_quote.txt
# Saved data for EDV to EDV_full_quote.txt
# Saved data for BSL to BSL_full_quote.txt
# No data returned from FMP for symbol VCX
# Fallback to Yahoo Finance for symbol VCX
# Saved data for VCX to VCX_full_quote.txt
# No data returned from FMP for symbol YAL
# Fallback to Yahoo Finance for symbol YAL
# Saved data for YAL to YAL_full_quote.txt
# Saved data for AFI to AFI_full_quote.txt
# Saved data for GPT to GPT_full_quote.txt
# No data returned from FMP for symbol PLS
# Fallback to Yahoo Finance for symbol PLS
# Saved data for PLS to PLS_full_quote.txt
# Saved data for TPG to TPG_full_quote.txt
# No data returned from FMP for symbol GQG
# Fallback to Yahoo Finance for symbol GQG
# Saved data for GQG to GQG_full_quote.txt
# Saved data for ORI to ORI_full_quote.txt
# Saved data for MGR to MGR_full_quote.txt
# Saved data for WOR to WOR_full_quote.txt
# Saved data for ALD to ALD_full_quote.txt
# No data returned from FMP for symbol SEK
# Fallback to Yahoo Finance for symbol SEK
# Saved data for SEK to SEK_full_quote.txt
# Saved data for EVN to EVN_full_quote.txt
# No data returned from FMP for symbol JBH
# Fallback to Yahoo Finance for symbol JBH
# Saved data for JBH to JBH_full_quote.txt
# Saved data for ALX to ALX_full_quote.txt
# No data returned from FMP for symbol DXS
# Fallback to Yahoo Finance for symbol DXS
# Saved data for DXS to DXS_full_quote.txt
# No data returned from FMP for symbol SDF
# Fallback to Yahoo Finance for symbol SDF
# Saved data for SDF to SDF_full_quote.txt
# Saved data for BEN to BEN_full_quote.txt
# Saved data for AGL to AGL_full_quote.txt
# No data returned from FMP for symbol AZJ
# Fallback to Yahoo Finance for symbol AZJ
# Saved data for AZJ to AZJ_full_quote.txt
# No data returned from FMP for symbol TNE
# Fallback to Yahoo Finance for symbol TNE
# Saved data for TNE to TNE_full_quote.txt
# No data returned from FMP for symbol WHC
# Fallback to Yahoo Finance for symbol WHC
# Saved data for WHC to WHC_full_quote.txt
# Saved data for TLX to TLX_full_quote.txt
# No data returned from FMP for symbol CHC
# Fallback to Yahoo Finance for symbol CHC
# Saved data for CHC to CHC_full_quote.txt
# No data returned from FMP for symbol HVN
# Fallback to Yahoo Finance for symbol HVN
# Saved data for HVN to HVN_full_quote.txt
# No data returned from FMP for symbol LYC
# Fallback to Yahoo Finance for symbol LYC
# Saved data for LYC to LYC_full_quote.txt
# No data returned from FMP for symbol IPL
# Fallback to Yahoo Finance for symbol IPL
# Saved data for IPL to IPL_full_quote.txt
# Saved data for FLT to FLT_full_quote.txt
# No data returned from FMP for symbol LLC
# Fallback to Yahoo Finance for symbol LLC
# Saved data for LLC to LLC_full_quote.txt
# No data returned from FMP for symbol AWC
# Fallback to Yahoo Finance for symbol AWC
# Saved data for AWC to AWC_full_quote.txt
# No data returned from FMP for symbol IGO
# Fallback to Yahoo Finance for symbol IGO
# Saved data for IGO to IGO_full_quote.txt
# No data returned from FMP for symbol IEL
# Fallback to Yahoo Finance for symbol IEL
# Saved data for IEL to IEL_full_quote.txt
# No data returned from FMP for symbol BOQ
# Fallback to Yahoo Finance for symbol BOQ
# Saved data for BOQ to BOQ_full_quote.txt
# Saved data for NHC to NHC_full_quote.txt
# No data returned from FMP for symbol HUB
# Fallback to Yahoo Finance for symbol HUB
# Saved data for HUB to HUB_full_quote.txt
# Saved data for SFR to SFR_full_quote.txt
# Saved data for VNT to VNT_full_quote.txt
# No data returned from FMP for symbol SUL
# Fallback to Yahoo Finance for symbol SUL
# Saved data for SUL to SUL_full_quote.txt
# Saved data for PDN to PDN_full_quote.txt
# Saved data for AMP to AMP_full_quote.txt
# No data returned from FMP for symbol BFL
# Fallback to Yahoo Finance for symbol BFL
# Saved data for BFL to BFL_full_quote.txt
# No data returned from FMP for symbol ILU
# Fallback to Yahoo Finance for symbol ILU
# Saved data for ILU to ILU_full_quote.txt
# Saved data for NEU to NEU_full_quote.txt
# Saved data for DRR to DRR_full_quote.txt
# Saved data for SGM to SGM_full_quote.txt
# No data returned from FMP for symbol CTD
# Fallback to Yahoo Finance for symbol CTD
# Saved data for CTD to CTD_full_quote.txt
# No data returned from FMP for symbol IFL
# Fallback to Yahoo Finance for symbol IFL
# Saved data for IFL to IFL_full_quote.txt
# Saved data for MFG to MFG_full_quote.txt
# Saved data for KAR to KAR_full_quote.txt
# No data returned from FMP for symbol DYL
# Fallback to Yahoo Finance for symbol DYL
# Saved data for DYL to DYL_full_quote.txt
# Saved data for CCP to CCP_full_quote.txt
# No data returned from FMP for symbol TPW
# Fallback to Yahoo Finance for symbol TPW
# Saved data for TPW to TPW_full_quote.txt
# No data returned from FMP for symbol OML
# Fallback to Yahoo Finance for symbol OML
# Saved data for OML to OML_full_quote.txt
# No data returned from FMP for symbol QRI
# Fallback to Yahoo Finance for symbol QRI
# Saved data for QRI to QRI_full_quote.txt
# No data returned from FMP for symbol ADH
# Fallback to Yahoo Finance for symbol ADH
# Saved data for ADH to ADH_full_quote.txt
# Saved data for EML to EML_full_quote.txt
# No data returned from FMP for symbol GNG
# Fallback to Yahoo Finance for symbol GNG
# Saved data for GNG to GNG_full_quote.txt
# Saved data for DUG to DUG_full_quote.txt
# No data returned from FMP for symbol WC8
# Fallback to Yahoo Finance for symbol WC8
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WC8?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WC8&crumb=v44MHz9nj3f
# Saved data for WC8 to WC8_full_quote.txt
# No data returned from FMP for symbol KSL
# Fallback to Yahoo Finance for symbol KSL
# Saved data for KSL to KSL_full_quote.txt
# Saved data for TPC to TPC_full_quote.txt
# No data returned from FMP for symbol PPE
# Fallback to Yahoo Finance for symbol PPE
# Saved data for PPE to PPE_full_quote.txt
# No data returned from FMP for symbol AXI
# Fallback to Yahoo Finance for symbol AXI
# Saved data for AXI to AXI_full_quote.txt
