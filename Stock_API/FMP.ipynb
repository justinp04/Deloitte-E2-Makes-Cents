# %%
# aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY

# %%
# !pip install yfinance

# %%
import requests
import os

API_KEY = 'aSFV2BaLN9XnBc35RAfTax2pA2zIGqKY'

# List of all Autralian Stock Markets
symbols = ['CBA', 'BHP', 'RIO', 'CSL', 'NAB', 'WBC', 'ANZ', 'WES', 'MQG', 'GMG', 'FMG', 'WDS', 'RMD', 'TLS', 'WOW', 'TCL', 'ALL', 'WTC', 'QBE', 'REA', 'STO', 'COL', 'JHX', 'AMC', 'SUN', 'COH', 'BXB', 'XRO', 'ORG', 'SCG', 'REH', 'IAG', 'FPH', 'CPU', 'NST', 'SVW', 'PME', 'S32', 'SHL', 'CAR', 'SOL', 'ASX', 'TLC', 'SGP', 'MPL', 'RHC', 'MIN', 'QAN', 'APA', 'NXT', 'TWE', 'EDV', 'BSL', 'VCX', 'YAL', 'AFI', 'GPT', 'PLS', 'TPG', 'GQG', 'ORI', 'MGR', 'WOR', 'ALD', 'SEK', 'EVN', 'JBH', 'ALX', 'DXS', 'SDF', 'BEN', 'AGL', 'AZJ', 'TNE', 'WHC', 'TLX', 'CHC', 'HVN', 'LYC', 'IPL', 'FLT', 'LLC', 'AWC', 'IGO', 'IEL', 'BOQ', 'NHC', 'HUB', 'SFR', 'VNT', 'SUL', 'PDN', 'AMP', 'BFL', 'ILU', 'NEU', 'DRR', 'SGM', 'CTD', 'IFL', 'MFG', 'KAR', 'DYL', 'CCP', 'TPW', 'OML', 'QRI', 'ADH', 'EML', 'GNG', 'DUG', 'WC8', 'KSL', 'TPC', 'PPE', 'AXI']


# Function to get full quote for a stock
def get_full_quote(symbol):
    url = f'https://financialmodelingprep.com/api/v3/quote/{symbol}?apikey={API_KEY}'
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        data = response.json()
        if data and isinstance(data, list) and len(data) > 0:
            return data
        else:
            print(f'No data returned for symbol {symbol}')
            return None
    except requests.RequestException as e:
        print(f'Error fetching data for symbol {symbol}: {e}')
        return None

#  Function to save data to a .txt file
def save_to_txt(data, directory, filename):
    if not os.path.exists(directory):
        os.makedirs(directory)

    file_path = os.path.join(directory, filename)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(str(data))  # Convert data to a string representation for saving


# Directory to save the quotes
directory = 'full_quote'

# Fetch and save quotes for each symbol
for symbol in symbols:
    full_quote = get_full_quote(symbol)
    if full_quote:  # Only save if data is returned
        filename = f'{symbol}_full_quote.txt'
        save_to_txt(full_quote, directory, filename)
        print(f'Saved data for {symbol} to {filename}')
    else:
        print(f'No data to save for {symbol}')
# Out:
# No data returned for symbol CBA
# No data to save for CBA
# Saved data for BHP to BHP_full_quote.txt
# Saved data for RIO to RIO_full_quote.txt
# Saved data for CSL to CSL_full_quote.txt
# No data returned for symbol NAB
# No data to save for NAB
# No data returned for symbol WBC
# No data to save for WBC
# No data returned for symbol ANZ
# No data to save for ANZ
# Saved data for WES to WES_full_quote.txt
# No data returned for symbol MQG
# No data to save for MQG
# No data returned for symbol GMG
# No data to save for GMG
# No data returned for symbol FMG
# No data to save for FMG
# Saved data for WDS to WDS_full_quote.txt
# Saved data for RMD to RMD_full_quote.txt
# Saved data for TLS to TLS_full_quote.txt
# Saved data for WOW to WOW_full_quote.txt
# No data returned for symbol TCL
# No data to save for TCL
# Saved data for ALL to ALL_full_quote.txt
# No data returned for symbol WTC
# No data to save for WTC
# No data returned for symbol QBE
# No data to save for QBE
# No data returned for symbol REA
# No data to save for REA
# No data returned for symbol STO
# No data to save for STO
# Saved data for COL to COL_full_quote.txt
# Saved data for JHX to JHX_full_quote.txt
# Saved data for AMC to AMC_full_quote.txt
# Saved data for SUN to SUN_full_quote.txt
# No data returned for symbol COH
# No data to save for COH
# No data returned for symbol BXB
# No data to save for BXB
# No data returned for symbol XRO
# No data to save for XRO
# Saved data for ORG to ORG_full_quote.txt
# No data returned for symbol SCG
# No data to save for SCG
# No data returned for symbol REH
# No data to save for REH
# Saved data for IAG to IAG_full_quote.txt
# Saved data for FPH to FPH_full_quote.txt
# No data returned for symbol CPU
# No data to save for CPU
# No data returned for symbol NST
# No data to save for NST
# No data returned for symbol SVW
# No data to save for SVW
# Saved data for PME to PME_full_quote.txt
# No data returned for symbol S32
# No data to save for S32
# No data returned for symbol SHL
# No data to save for SHL
# Saved data for CAR to CAR_full_quote.txt
# Saved data for SOL to SOL_full_quote.txt
# Saved data for ASX to ASX_full_quote.txt
# Saved data for TLC to TLC_full_quote.txt
# No data returned for symbol SGP
# No data to save for SGP
# No data returned for symbol MPL
# No data to save for MPL
# No data returned for symbol RHC
# No data to save for RHC
# Saved data for MIN to MIN_full_quote.txt
# No data returned for symbol QAN
# No data to save for QAN
# Saved data for APA to APA_full_quote.txt
# Saved data for NXT to NXT_full_quote.txt
# No data returned for symbol TWE
# No data to save for TWE
# Saved data for EDV to EDV_full_quote.txt
# Saved data for BSL to BSL_full_quote.txt
# No data returned for symbol VCX
# No data to save for VCX
# No data returned for symbol YAL
# No data to save for YAL
# Saved data for AFI to AFI_full_quote.txt
# Saved data for GPT to GPT_full_quote.txt
# No data returned for symbol PLS
# No data to save for PLS
# Saved data for TPG to TPG_full_quote.txt
# No data returned for symbol GQG
# No data to save for GQG
# Saved data for ORI to ORI_full_quote.txt
# Saved data for MGR to MGR_full_quote.txt
# Saved data for WOR to WOR_full_quote.txt
# Saved data for ALD to ALD_full_quote.txt
# No data returned for symbol SEK
# No data to save for SEK
# Saved data for EVN to EVN_full_quote.txt
# No data returned for symbol JBH
# No data to save for JBH
# Saved data for ALX to ALX_full_quote.txt
# No data returned for symbol DXS
# No data to save for DXS
# No data returned for symbol SDF
# No data to save for SDF
# Saved data for BEN to BEN_full_quote.txt
# Saved data for AGL to AGL_full_quote.txt
# No data returned for symbol AZJ
# No data to save for AZJ
# No data returned for symbol TNE
# No data to save for TNE
# No data returned for symbol WHC
# No data to save for WHC
# Saved data for TLX to TLX_full_quote.txt
# No data returned for symbol CHC
# No data to save for CHC
# No data returned for symbol HVN
# No data to save for HVN
# No data returned for symbol LYC
# No data to save for LYC
# No data returned for symbol IPL
# No data to save for IPL
# Saved data for FLT to FLT_full_quote.txt
# No data returned for symbol LLC
# No data to save for LLC
# No data returned for symbol AWC
# No data to save for AWC
# No data returned for symbol IGO
# No data to save for IGO
# No data returned for symbol IEL
# No data to save for IEL
# No data returned for symbol BOQ
# No data to save for BOQ
# Saved data for NHC to NHC_full_quote.txt
# No data returned for symbol HUB
# No data to save for HUB
# Saved data for SFR to SFR_full_quote.txt
# Saved data for VNT to VNT_full_quote.txt
# No data returned for symbol SUL
# No data to save for SUL
# Saved data for PDN to PDN_full_quote.txt
# Saved data for AMP to AMP_full_quote.txt
# No data returned for symbol BFL
# No data to save for BFL
# No data returned for symbol ILU
# No data to save for ILU
# Saved data for NEU to NEU_full_quote.txt
# Saved data for DRR to DRR_full_quote.txt
# Saved data for SGM to SGM_full_quote.txt
# No data returned for symbol CTD
# No data to save for CTD
# No data returned for symbol IFL
# No data to save for IFL
# Saved data for MFG to MFG_full_quote.txt
# Saved data for KAR to KAR_full_quote.txt
# No data returned for symbol DYL
# No data to save for DYL
# Saved data for CCP to CCP_full_quote.txt
# No data returned for symbol TPW
# No data to save for TPW
# No data returned for symbol OML
# No data to save for OML
# No data returned for symbol QRI
# No data to save for QRI
# No data returned for symbol ADH
# No data to save for ADH
# Saved data for EML to EML_full_quote.txt
# No data returned for symbol GNG
# No data to save for GNG
# Saved data for DUG to DUG_full_quote.txt
# No data returned for symbol WC8
# No data to save for WC8
# No data returned for symbol KSL
# No data to save for KSL
# Saved data for TPC to TPC_full_quote.txt
# No data returned for symbol PPE
# No data to save for PPE
# No data returned for symbol AXI
# No data to save for AXI
